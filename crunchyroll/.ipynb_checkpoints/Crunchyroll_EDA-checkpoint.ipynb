# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import random

def explode(df, lst_cols, fill_value=''):
    # make sure `lst_cols` is a list
    if lst_cols and not isinstance(lst_cols, list):
        lst_cols = [lst_cols]
    # all columns except `lst_cols`
    idx_cols = df.columns.difference(lst_cols)

    # calculate lengths of lists
    lens = df[lst_cols[0]].str.len()

    if (lens > 0).all():
        # ALL lists in cells aren't empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .loc[:, df.columns]
    else:
        # at least one list in cells is empty
        return pd.DataFrame({
            col:np.repeat(df[col].values, lens)
            for col in idx_cols
        }).assign(**{col:np.concatenate(df[col].values) for col in lst_cols}) \
          .append(df.loc[lens==0, idx_cols]).fillna(fill_value) \
          .loc[:, df.columns]

# %%
def top_n(df, n, series):
    return df.sort_values(series, ascending = False).iloc[:n]

# %%
home = pd.read_csv("crunchy_home.csv")

home["similar"] = home["similar"].apply(lambda x: x.split("::"))
home["tags"] = home["tags"].apply(lambda x: x.split("::"))


reviews = pd.read_csv("crunchy_review.csv")

main = pd.read_csv("crunchy_main.csv")

main["similar"] = main["similar"].apply(lambda x: x.split("::"))
main["tags"] = main["tags"].apply(lambda x: x.split("::"))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Shows that are most said to be similar

# %%
similars = explode(pd.DataFrame(home["similar"]),"similar")

# %%
similars["similar"].value_counts().head()
# Out:
# BORUTO: NARUTO NEXT GENERATIONS    456
# One Piece                          432
# Sword Art Online                   409
# Fairy Tail                         399
# Gabriel DropOut                     47
# Name: similar, dtype: int64

# %%
similars["similar"].value_counts()
# Out:
# BORUTO: NARUTO NEXT GENERATIONS                   456
# One Piece                                         432
# Sword Art Online                                  409
# Fairy Tail                                        399
# Gabriel DropOut                                    47
# Nyanko Days                                        46
# Ai-Mai-Mi Surgical Friends                         41
# FOREST FAIRY FIVE                                  32
# Cheating Craft                                     32
# Chiruran 1/2                                       31
# Hinako Note                                        29
# Love Rice                                          25
# Miss Bernard said.                                 25
# The Reflection                                     15
# Hand Shakers                                       15
# Mobile Suit Gundam Wing                            14
# RADIANT                                            14
# Hakata Tonkotsu Ramens                             14
# Golden Time                                        14
# That Time I Got Reincarnated as a Slime            14
# Aooni The Blue Monster                             14
# Taboo Tattoo                                       14
# Mobile Suit Gundam Wing ENDLESS WALTZ              13
# RWBY VOLUME 1-3: The Beginning (Japanese Dub)      12
# The Rising of the Shield Hero                      12
# Minami Kamakura High School Girls Cycling Club     12
# GeGeGe no Kitaro                                   12
# Overlord                                           12
# Girly Air Force                                    12
# Momo Kyun Sword                                    12
#                                                  ...
# Hanasakeru Seishonen                                1
# Sabagebu!  - Survival Game Club! –                  1
# Yokuwakaru Gendai Maho                              1
# 11eyes                                              1
# Hakuoki Reimeiroku                                  1
# Saint Seiya Omega                                   1
# Hakuoki Season 1                                    1
# Sengoku Collection (Parallel World Samurai)         1
# gdgd Fairies                                        1
# URAHARA                                             1
# Brave Witches                                       1
# OZMAFIA!!                                           1
# Phi Brain                                           1
# Nogizaka Haruka no Himitsu                          1
# You and Me                                          1
# Kaasan Mom's Life                                   1
# SENGOKU NIGHT BLOOD                                 1
# Taisho Mebiusline Chicchaisan                       1
# Saki                                                1
# The Price of Smiles                                 1
# School Days                                         1
# Hourou Musuko Wandering Son                         1
# RWBY                                                1
# Walkure Romanze                                     1
# Junji Ito Collection                                1
# Happiness!                                          1
# Magi                                                1
# Nobunaga Concerto                                   1
# The Royal Tutor                                     1
# Chance Pop Session                                  1
# Name: similar, Length: 473, dtype: int64

# %% [markdown]
# ## TAGS

# %% [markdown]
# ### Most Common

# %%
tags = explode(pd.DataFrame(home["tags"]),"tags")

# %%
tags["tags"].value_counts().head(20)
# Out:
# comedy                       244
# anime                        181
# action                       181
# slice of life                155
# fantasy                      147
# romance                      116
# adventure                    100
# TV TOKYO                      93
# drama                         89
# Aniplex of America            89
# shoujo                        84
# shounen                       70
# Kadokawa Pictures Inc.        62
# science fiction               61
# seinen                        55
# Discotek Media                47
# Showgate                      46
# ecchi                         41
# crunchyroll co-production     39
# mecha                         38
# Name: tags, dtype: int64

# %% [markdown]
# ### Agg_review and Num Eps

# %%
tags_agg_num = (explode(home,"tags").
                pivot_table(index="tags",
                            values=["agg_review","num_eps"],
                            aggfunc=[np.mean,'size']))

# %%
agg_review_eps_TAGS = (tags_agg_num[tags_agg_num["size"][0] >= 30]["mean"].
 sort_values("agg_review",ascending=False))

agg_review_eps_TAGS.head()
# Out:
#                     agg_review    num_eps
# tags
# sports                4.433333  43.066667
# anime                 4.395028  41.558011
# drama                 4.393258  27.292135
# Aniplex of America    4.376404  24.089888
# shounen               4.300000  66.457143

# %%
agg_review_eps_TAGS.plot.scatter("num_eps","agg_review")

# %% [markdown]
# ### Props of 1, 2, 3, 4, 5 Ratings

# %%
tags_numvals = (explode(home,"tags").
                pivot_table(index="tags",
                            values=["1", "2", "3", "4", "5"],
                            aggfunc=np.sum))

# %%
tags_numvals["total"] = tags_numvals.sum(axis = 1)

# %%
top_tags = top_n(tags_numvals, 100, "total")

# %%
top_tags_norm = (top_tags[["1","2","3","4","5"]].divide(top_tags["total"],axis = 0).
                 join(top_tags["total"]))

# %%
top_n(top_n(top_tags_norm, 100, "total"), 20, "1")
# Out:
#                                1         2         3         4         5  \
# tags
# Showgate                0.070135  0.060716  0.092885  0.163020  0.613244
# Kadokawa Pictures Inc.  0.046493  0.031672  0.057649  0.147749  0.716437
# Toei Animation          0.044170  0.021084  0.047821  0.104240  0.782686
# adventure               0.041901  0.031870  0.052021  0.129490  0.744718
# action                  0.041161  0.031300  0.052926  0.131703  0.742910
# visual novel            0.036841  0.019598  0.048295  0.139603  0.755663
# shounen                 0.033910  0.021719  0.037423  0.106548  0.800399
# ecchi                   0.033246  0.022929  0.053674  0.157582  0.732569
# mecha                   0.031675  0.021847  0.052062  0.137393  0.757022
# GONZO                   0.031327  0.010816  0.035408  0.118265  0.804184
# gonzo                   0.031266  0.009668  0.035586  0.121053  0.802427
# science fiction         0.028527  0.022041  0.049650  0.141890  0.757892
# Marvelous AQL Inc.      0.028404  0.013309  0.043116  0.139680  0.775491
# fantasy                 0.028361  0.020849  0.038826  0.113118  0.798846
# seinen                  0.027696  0.021483  0.049527  0.148522  0.752772
# harem                   0.027461  0.015412  0.047436  0.152996  0.756695
# masashi kishimoto       0.027329  0.003861  0.016892  0.049047  0.902872
# itachi                  0.027329  0.003861  0.016892  0.049047  0.902872
# crunchyroll naruto      0.027329  0.003861  0.016892  0.049047  0.902872
# ninja                   0.026623  0.004409  0.018379  0.055136  0.895454
#
#                           total
# tags
# Showgate                 6901.0
# Kadokawa Pictures Inc.  12819.0
# Toei Animation           8490.0
# adventure               33794.0
# action                  64600.0
# visual novel            15716.0
# shounen                 37570.0
# ecchi                   19190.0
# mecha                   15059.0
# GONZO                    9800.0
# gonzo                    9723.0
# science fiction         17422.0
# Marvelous AQL Inc.      23518.0
# fantasy                 73481.0
# seinen                  17223.0
# harem                   24981.0
# masashi kishimoto       16576.0
# itachi                  16576.0
# crunchyroll naruto      16576.0
# ninja                   17466.0

# %%
top_n(top_n(top_tags_norm, 100, "total"), 20, "5")
# Out:
#                                1         2         3         4         5  \
# tags
# skip beat               0.006530  0.001333  0.007463  0.046312  0.938362
# stardom                 0.006530  0.001333  0.007463  0.046312  0.938362
# kyoko mogami            0.006530  0.001333  0.007463  0.046312  0.938362
# idol                    0.006788  0.001985  0.008645  0.050717  0.931865
# reborn                  0.009015  0.003750  0.010531  0.046673  0.930030
# tsuna sawada            0.009015  0.003750  0.010531  0.046673  0.930030
# hayato gokudera         0.009015  0.003750  0.010531  0.046673  0.930030
# akira amano             0.009015  0.003750  0.010531  0.046673  0.930030
# takeshi yamamoto        0.009015  0.003750  0.010531  0.046673  0.930030
# D-Rights                0.009015  0.003750  0.010531  0.046673  0.930030
# katekyō hitman reborn   0.009015  0.003750  0.010531  0.046673  0.930030
# the varia               0.009015  0.003750  0.010531  0.046673  0.930030
# katekyou hitman reborn  0.009015  0.003750  0.010531  0.046673  0.930030
# gintama                 0.011673  0.003949  0.010883  0.044673  0.928822
# hideaki sorachi         0.011673  0.003949  0.010883  0.044673  0.928822
# shinpachi shimura       0.011673  0.003949  0.010883  0.044673  0.928822
# crunchyroll gintama     0.011673  0.003949  0.010883  0.044673  0.928822
# gin tama                0.011673  0.003949  0.010883  0.044673  0.928822
# gintoki                 0.011673  0.003949  0.010883  0.044673  0.928822
# shinsengumi             0.011864  0.004100  0.011428  0.045887  0.926721
#
#                           total
# tags
# skip beat               15007.0
# stardom                 15007.0
# kyoko mogami            15007.0
# idol                    15616.0
# reborn                  12534.0
# tsuna sawada            12534.0
# hayato gokudera         12534.0
# akira amano             12534.0
# takeshi yamamoto        12534.0
# D-Rights                12534.0
# katekyō hitman reborn   12534.0
# the varia               12534.0
# katekyou hitman reborn  12534.0
# gintama                 11394.0
# hideaki sorachi         11394.0
# shinpachi shimura       11394.0
# crunchyroll gintama     11394.0
# gin tama                11394.0
# gintoki                 11394.0
# shinsengumi             11463.0

# %% [markdown]
# ## Reviews

# %%
def clean_data(df, *argv):
    df1 = df.copy()
    for series in argv:
        df1[series] = df1[series].str.lower()
        df1[series] = df1[series].str.replace("\n","")
        df1[series] = df1[series].str.replace("\r","")
        df1[series] = df1[series].str.replace("-"," ")
        df1[series] = df1[series].str.replace("[^\w\s]","")
        df1[series] = df1[series].str.strip()
    df1 = df1.fillna("None")
    df1 = df1.replace("", "missing")
    return df1

# %%
reviews
# Out:
#                    show                    datetime rating  \
# 0              07-ghost  \n      Sep 19, 2014\n          2
# 1              07-ghost  \n      Jul 27, 2013\n          5
# 2              07-ghost   \n      Aug 3, 2012\n          4
# 3              07-ghost  \n      Feb 22, 2015\n          2
# 4              07-ghost  \n      Jan 27, 2013\n          3
# 5              07-ghost  \n      Jan 10, 2013\n          2
# 6              07-ghost   \n      Jun 4, 2013\n          5
# 7              07-ghost  \n      Dec 11, 2012\n          4
# 8              07-ghost   \n      Dec 1, 2013\n          5
# 9              07-ghost  \n      May 12, 2013\n          4
# 10             07-ghost   \n      Apr 2, 2011\n          5
# 11             07-ghost  \n      Sep 30, 2009\n          5
# 12             07-ghost  \n      Dec 22, 2015\n          3
# 13             07-ghost  \n      Dec 11, 2015\n          2
# 14             07-ghost  \n      Oct 24, 2015\n          4
# 15             07-ghost  \n      Dec 15, 2014\n          1
# 16             07-ghost  \n      Jan 14, 2014\n          4
# 17             07-ghost  \n      Nov 28, 2013\n          5
# 18             07-ghost  \n      Sep 23, 2013\n          4
# 19             07-ghost  \n      Aug 29, 2013\n          4
# 20             07-ghost  \n      Aug 21, 2013\n          4
# 21             07-ghost   \n      Aug 3, 2013\n          4
# 22             07-ghost   \n      Jul 3, 2013\n          4
# 23             07-ghost  \n      Mar 27, 2013\n          5
# 24             07-ghost  \n      Aug 14, 2012\n          4
# 25             07-ghost  \n      Mar 10, 2012\n          5
# 26             07-ghost  \n      Dec 23, 2011\n          5
# 27             07-ghost   \n      Dec 2, 2011\n          4
# 28             07-ghost  \n      Nov 23, 2011\n          5
# 29             07-ghost  \n      Jun 28, 2011\n          5
# ...                 ...                         ...    ...
# 73319  zombie-land-saga  \n      Dec 22, 2018\n          5
# 73320  zombie-land-saga  \n      Dec 22, 2018\n          5
# 73321  zombie-land-saga  \n      Dec 21, 2018\n          5
# 73322  zombie-land-saga  \n      Dec 21, 2018\n          4
# 73323  zombie-land-saga  \n      Dec 21, 2018\n          5
# 73324  zombie-land-saga  \n      Dec 20, 2018\n          5
# 73325  zombie-land-saga  \n      Dec 20, 2018\n          5
# 73326  zombie-land-saga  \n      Dec 20, 2018\n          5
# 73327  zombie-land-saga  \n      Dec 15, 2018\n          5
# 73328  zombie-land-saga  \n      Dec 13, 2018\n          5
# 73329  zombie-land-saga  \n      Dec 13, 2018\n          5
# 73330  zombie-land-saga   \n      Dec 1, 2018\n          5
# 73331  zombie-land-saga  \n      Nov 27, 2018\n          4
# 73332  zombie-land-saga   \n      Nov 8, 2018\n          3
# 73333  zombie-land-saga   \n      Nov 3, 2018\n          4
# 73334  zombie-land-saga  \n      Oct 27, 2018\n          4
# 73335  zombie-land-saga  \n      Oct 19, 2018\n          5
# 73336  zombie-land-saga  \n      Oct 18, 2018\n          5
# 73337  zombie-land-saga  \n      Oct 17, 2018\n          5
# 73338  zombie-land-saga  \n      Oct 16, 2018\n          5
# 73339  zombie-land-saga  \n      Oct 14, 2018\n          5
# 73340  zombie-land-saga  \n      Oct 13, 2018\n          5
# 73341  zombie-land-saga  \n      Oct 13, 2018\n          5
# 73342  zombie-land-saga   \n      Oct 9, 2018\n          5
# 73343  zombie-land-saga   \n      Oct 5, 2018\n          5
# 73344  zombie-land-saga   \n      Oct 4, 2018\n          5
# 73345  zombie-land-saga   \n      Oct 4, 2018\n          5
# 73346  zombie-land-saga   \n      Oct 4, 2018\n          5
# 73347       zombie-loan  \n      Mar 11, 2018\n          5
# 73348       zombie-loan  \n      Dec 12, 2017\n          2
#
#                                                   review  \
# 0      \n              I have NO clue why this show i...
# 1      \n               Synopsis: \r\nMain character ...
# 2      \n              I really liked this show. A de...
# 3      \n              The first episode throws off t...
# 4      \n              Well... I love the opening and...
# 5      \n              The plot is simple and predict...
# 6      \n              The graphics were wonderful in...
# 7      \n               Reviewed:  December 2012 \r\n...
# 8      \n              I am absolutely in LOVE with t...
# 9      \n              If there's one thing I'd have ...
# 10     \n               Okay, i may be exaggerating t...
# 11     \n              Okay, giving this anime a comp...
# 12     \n              This show had so much potentia...
# 13     \n              The story line in general wasn...
# 14     \n              It's a pretty good anime which...
# 15     \n              Such an awesome anime that com...
# 16     \n              This show suprised me. I didn'...
# 17     \n              So basically the storyline is ...
# 18     \n              I  love  this anime!!! The sto...
# 19     \n              This show has a fantastic art ...
# 20     \n              I wish there was more, it was ...
# 21     \n              I think this is a okay anime i...
# 22     \n              This was the first anime I wat...
# 23     \n              This was a show that I randoml...
# 24     \n              As you submerge yourself withi...
# 25     \n              This is actually the best anim...
# 26     \n              This was pretty much great eve...
# 27     \n              I'm pleased with this gem of t...
# 28     \n              So in the six short years I've...
# 29     \n              07-Ghost is an amazing anime.....
# ...                                                  ...
# 73319  \n              what an absolute lad of a show...
# 73320  \n              ... and what a satisfying whim...
# 73321  \n              At first, it was ridiculous an...
# 73322  \n              Pretty fun take on the idol an...
# 73323  \n              Without hesitation, I rank "Zo...
# 73324  \n              Idols, zombies, rural revitali...
# 73325  \n              The dark underside of the Japa...
# 73326  \n              This anime seriously blew me a...
# 73327  \n              This series reels you in with ...
# 73328  \n              Like literally, I look forward...
# 73329  \n               I wait in anticipation for ea...
# 73330  \n              Most idol animes that I watch ...
# 73331  \n              I found myself enjoying it. I ...
# 73332  \n              ~~Review written as of conclus...
# 73333  \n              4 Eps Down \r\n \r\nSo far thi...
# 73334  \n              TL;DR \r\nDo I love this show?...
# 73335  \n              3rd episode and it's been fun....
# 73336  \n              Those three words I feel descr...
# 73337  \n              I'm writing this only 2 episod...
# 73338  \n              There's only one good characte...
# 73339  \n              I hadn't heard or read anythin...
# 73340  \n              WE WILL TAKE OVER SAGA!!!  \r\...
# 73341  \n              Zombie Girls that Sing/Rap?! I...
# 73342  \n              Let me just... gently push thi...
# 73343  \n              I've been watching anime for l...
# 73344  \n              I've been getting tired of zom...
# 73345  \n              First episode review,  \r\n \r...
# 73346  \n              The first episode had me laugh...
# 73347  \n              I actually liked this show but...
# 73348  \n              It is taking all of me to fini...
#
#                                                  summary  \
# 0      The few good moments aren't worth the boring s...
# 1                            I demand season two pronto!
# 2                                   A good show but.....
# 3                                  Bad pacin... ...g ...
# 4                                 Just an average rating
# 5          The first episode is great, but after that...
# 6          Craving for more seasons, and fills that need
# 7      Season 1 of 07 Ghost will leave viewers wantin...
# 8                                   New Season Please!!!
# 9                    A Show that leaves you wanting more
# 10                           The BEST Anime of ALL TIME!
# 11                                 Something to look for
# 12     No season two.  Season one is alright, but mis...
# 13                 Underdeveloped and excessive elements
# 14               Pretty good, just a touch disappointing
# 15                     Great but such a horrible ending.
# 16                                Wow! It's really good!
# 17                                 A Unique Storyline...
# 18     Awesome indeed, yet lacks a good battle when i...
# 19             Not for some, but great for everyone else
# 20                         Good series.  Worth watching.
# 21                           My personal 07 GHOST Review
# 22                            First anime on CrunchyRoll
# 23     .............(that was my breath being taken a...
# 24                                  O7-Ghost By: Verases
# 25            This was the best thing i've seen in ages!
# 26                            Please a Season 2 Soon....
# 27                             Not what I was expecting.
# 28                             One Of the Best I've Seen
# 29                                  07-Ghost, A must see
# ...                                                  ...
# 73319                           The Legendary Tae Yamada
# 73320      Not a zombie person, but watched on a whim...
# 73321               Quirky titles becomes something more
# 73322                    Zombie Idols done right… mostly
# 73323                    Best Anime for late 2018 season
# 73324  It has everything, and everything works out pe...
# 73325                  Pull Yourselves Together and Sing
# 73326              Just try one episode at least, please
# 73327                            Stupidly Brilliant Saga
# 73328       This show is so funny, I can't stop watching
# 73329                        You Gotta Check This Out!!!
# 73330                          A Fun Twist to Idol Anime
# 73331  Wasn't what I expected, but that was a good thing
# 73332  Strong Start, Settles into a Groove, Performs ...
# 73333                               Continuous Reviews!!
# 73334            Best Surprise of The Season (Episode 6)
# 73335                           A lovely Halloween Treat
# 73336                               Cute. Funny. ABSURD.
# 73337      Potential for greatness! Can't wait for more!
# 73338                            So bad it's good lol xd
# 73339                        Completely caught off guard
# 73340                              Sugoi!!!!!!!!!!!!!!!!
# 73341           This is what I have been waiting for! xD
# 73342  "Just go with it" the anime! a first impressio...
# 73343             only one episode in and im blown away.
# 73344                       The first episode is amazing
# 73345            Zombie Idols Saving Saga, SURE WHY NOT.
# 73346                           Comedy zombies the anime
# 73347                   Wheres the rest of the episodes?
# 73348                      Uninteresting, average, snore
#
#                                                   useful
# 0      \n    43\n    out of\n    56\n     people foun...
# 1      \n    20\n    out of\n    22\n     people foun...
# 2      \n    9\n    out of\n    11\n     people found...
# 3      \n    10\n    out of\n    14\n     people foun...
# 4      \n    6\n    out of\n    6\n     people found ...
# 5      \n    12\n    out of\n    18\n     people foun...
# 6      \n    5\n    out of\n    7\n     people found ...
# 7      \n    5\n    out of\n    7\n     people found ...
# 8      \n    3\n    out of\n    4\n     people found ...
# 9      \n    3\n    out of\n    4\n     people found ...
# 10     \n    6\n    out of\n    10\n     people found...
# 11     \n    3\n    out of\n    4\n     people found ...
# 12     \n    1\n    out of\n    1\n     people found ...
# 13     \n    1\n    out of\n    1\n     people found ...
# 14     \n    1\n    out of\n    1\n     people found ...
# 15     \n    2\n    out of\n    3\n     people found ...
# 16     \n    2\n    out of\n    3\n     people found ...
# 17     \n    2\n    out of\n    3\n     people found ...
# 18     \n    2\n    out of\n    3\n     people found ...
# 19     \n    2\n    out of\n    3\n     people found ...
# 20     \n    2\n    out of\n    3\n     people found ...
# 21     \n    1\n    out of\n    1\n     people found ...
# 22     \n    1\n    out of\n    1\n     people found ...
# 23     \n    2\n    out of\n    3\n     people found ...
# 24     \n    2\n    out of\n    3\n     people found ...
# 25     \n    1\n    out of\n    1\n     people found ...
# 26     \n    1\n    out of\n    1\n     people found ...
# 27     \n    2\n    out of\n    3\n     people found ...
# 28     \n    2\n    out of\n    3\n     people found ...
# 29     \n    1\n    out of\n    1\n     people found ...
# ...                                                  ...
# 73319                                                NaN
# 73320                                                NaN
# 73321                                                NaN
# 73322                                                NaN
# 73323                                                NaN
# 73324                                                NaN
# 73325                                                NaN
# 73326                                                NaN
# 73327                                                NaN
# 73328                                                NaN
# 73329                                                NaN
# 73330                                                NaN
# 73331                                                NaN
# 73332                                                NaN
# 73333                                                NaN
# 73334                                                NaN
# 73335                                                NaN
# 73336                                                NaN
# 73337                                                NaN
# 73338                                                NaN
# 73339                                                NaN
# 73340                                                NaN
# 73341                                                NaN
# 73342                                                NaN
# 73343                                                NaN
# 73344                                                NaN
# 73345                                                NaN
# 73346                                                NaN
# 73347                                                NaN
# 73348                                                NaN
#
# [73349 rows x 6 columns]

# %%
clean_reviews = clean_data(reviews,"review","summary","useful")

clean_reviews["datetime"] = clean_reviews["datetime"]. \
                            str.replace("\n", ""). \
                            str.strip()

clean_reviews["datetime"] = pd.to_datetime(clean_reviews['datetime'],
                                           format='%b %d, %Y')

# %%
from nltk.corpus import stopwords

def tokenize(text_series, gram = 1):
    text_series = text_series.str.lower()
    
    text_series = text_series.str.replace("[^\w\s]","")
    
    sw = stopwords.words('english')
    token_list = text_series.apply(lambda row: [word for word in row.split() if word not in sw])
    if gram == 2:
        return token_list.apply(lambda x : zip(x[:-1], x[1:])).apply(list)
    return token_list

# %%
clean_reviews["tokens"] = tokenize(clean_reviews["review"])

review_tokens = clean_reviews["tokens"].apply(pd.Series) \
                .merge(clean_reviews, left_index = True, right_index = True) \
                .drop(["tokens"], axis = 1) \
                .melt(id_vars = ['show', 'datetime'], value_name = "tokens") \
                .drop("variable", axis = 1) \
                .dropna()

clean_reviews["tokens"] = tokenize(clean_reviews["review"], 2)

review_bigrams = clean_reviews["tokens"].apply(pd.Series) \
                .merge(clean_reviews, left_index = True, right_index = True) \
                .drop(["tokens"], axis = 1) \
                .melt(id_vars = ['show', 'datetime'], value_name = "tokens") \
                .drop("variable", axis = 1) \
                .dropna()

# %%
review_bigrams[review_bigrams["tokens"] == ("beautiful","animation")]["show"].value_counts().head()
# Out:
# yuri-on-ice                14
# your-lie-in-april           9
# yona-of-the-dawn            7
# beyond-the-boundary         6
# the-ancient-magus-bride     5
# Name: show, dtype: int64

# %%
review_tokens.head()
# Out:
#        show   datetime    tokens
# 0  07-ghost 2014-09-19      clue
# 1  07-ghost 2013-07-27  synopsis
# 2  07-ghost 2012-08-03    really
# 3  07-ghost 2015-02-22     first
# 4  07-ghost 2013-01-27      well

# %%
neg = pd.read_csv("negative-words.txt",sep = " "
            ,header = None,
            encoding="latin",
            names = ["words"])
pos = pd.read_csv("positive-words.txt",sep = " "
            ,header = None,
            encoding="latin",
            names = ["words"])

pos["type"] = "Positive"
neg["type"] = "Negative"

bing = pd.concat([neg,pos])

# %%
AFINN = pd.read_csv("AFINN/AFINN-111.txt", 
                    header = None, 
                    sep="\t", 
                    names = ["words","sentiment"])

# %%
tokens_afinn = pd.merge(review_tokens,
                       AFINN,
                       how="inner",
                       left_on="tokens",
                       right_on="words",
                       validate="many_to_one")

# %%
bing = bing.drop_duplicates("words")

tokens_bing = (pd.merge(review_tokens,
                       bing,
                       how="inner",
                       left_on="tokens",
                       right_on="words",
                       validate="many_to_one")
              )

tokens_bing["type"] = tokens_bing["type"].map({"Positive":1,
                                               "Negative":-1})

# %%
top_5_reviews = reviews["show"].value_counts().index[:5]

# %%
top_5_reviews_sent_a = tokens_afinn.pivot_table(index=["datetime"],
                        columns="show",
                        values="sentiment",aggfunc=np.sum)[top_5_reviews]

top_5_reviews_sent_b = tokens_bing.pivot_table(index=["datetime"],
                        columns="show",
                        values="type",aggfunc=np.sum)[top_5_reviews]

# %%
has_rating = clean_reviews[clean_reviews["rating"] != "No Rating"]
has_rating["rating"] = has_rating["rating"].astype("float64")

top_5_reviews_rating = has_rating.pivot_table(index=["datetime"],
                        columns="show",
                        values="rating",aggfunc=np.mean)[top_5_reviews]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
top_5_reviews_sent_gather = pd.melt(top_5_reviews_sent_a.reset_index(),
                                    "datetime",
                                     value_vars=top_5_reviews_sent_a.columns)

top_5_reviews_rating_gather = pd.melt(top_5_reviews_rating.reset_index(),
                                    "datetime",
                                     value_vars=top_5_reviews_sent.columns)

# %%
top_5_reviews_sent_gather["date_ord"] = (pd.to_datetime(top_5_reviews_sent_gather['datetime']).
                                             apply(lambda date: date.toordinal()))

# %%
from datetime import datetime

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(top_5_reviews_sent_gather, 
                  col="show", 
                  col_wrap=3, 
                  height=10,
                  aspect = 1,
                  sharex = False, 
                  sharey=False)

g = g.map(sns.regplot,
          "date_ord",
          "value",
          marker = ".").set_titles("{col_name} Sentiment of Reviews over Time",size = 30)

for ax in g.axes.flat:
    ax.set_xlabel('date')
    new_labels = [datetime.fromordinal(int(item)).date() for item in ax.get_xticks()]
    ax.set_xticklabels(new_labels)

plt.subplots_adjust(hspace=0.2, wspace=0.4)
plt.show()

# %%
top_5_reviews_rating_gather["date_ord"] = (pd.to_datetime(top_5_reviews_rating_gather['datetime']).
                                             apply(lambda date: date.toordinal()))

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(top_5_reviews_rating_gather, 
                  col="show", 
                  col_wrap=3, 
                  height=10,
                  aspect = 1,
                  sharex = False, 
                  sharey=False)

g = g.map(sns.regplot,
          "date_ord",
          "value",
          marker = ".").set_titles("{col_name} Rating over Time",size = 30)

for ax in g.axes.flat:
    ax.set_xlabel('date')
    new_labels = [datetime.fromordinal(int(item)).date() for item in ax.get_xticks()]
    ax.set_xticklabels(new_labels)

plt.subplots_adjust(hspace=0.2, wspace=0.2)
plt.show()

# %% [markdown]
# ## Markov Models

# %%
def train_uni_markov_chain(scripts):
    
    chain = {"<START>": []}
    for script in scripts:
        new_script = script.split(" ")
        chain["<START>"].append(new_script[0])
        for i in range(len(new_script)):
            if new_script[i] not in chain:
                if i == len(new_script) - 1:
                    chain[new_script[i]] = ["<END>"]
                else:
                    chain[new_script[i]] = [new_script[i+1]]
            else:
                if i == len(new_script) - 1:
                    chain[new_script[i]].append("<END>")
                else:
                    chain[new_script[i]].append(new_script[i+1])

    return chain

def generate_uni_new_script(chain):  
    
    words = []

    words.append(random.choice(chain["<START>"]))
    
    start_word = words[0]
    while start_word != "<END>":
        next_word = random.choice(chain[start_word])
        words.append(next_word)
        start_word = next_word

    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

def train_n_markov_chain(scripts, n = 2):
    initial = []
    for i in range(n):
        if i == (n - 1):
            initial.append("<START>")
        else:
            initial.append(None)
    initial = tuple(initial)
    chain = {initial: []}
    for script in scripts:
        new_scripts = script.split(" ")
        chain[initial].append(new_scripts[0])
        for i in range(len(new_scripts)):
            if len(new_scripts) > n:
                lookup = []
                for j in range(n):
                    lookup.append(new_scripts[i - n + j + 1])
                lookup = tuple(lookup)
                if i < n - 1:
                    buffer = []
                    for j in range(n - i - 2):
                        buffer.append(None)
                    if i == 0:
                        buffer.append("<START>")
                        buffer.append(new_scripts[i])
                    else:
                        buffer = list(save[1:])
                        buffer.append(new_scripts[i])
                    buffer = tuple(buffer)
                    save = buffer
                    chain[buffer] = [new_scripts[i+1]]
                elif lookup not in chain:
                    if i == len(new_scripts) - 1:
                        chain[lookup] = ["<END>"]
                    else:
                        chain[lookup] = [new_scripts[i+1]]
                else:
                    if i == len(new_scripts) - 1:
                        chain[lookup].append("<END>")
                    else:
                        chain[lookup].append(new_scripts[i+1])

    return chain

def generate_n_new_script(chain, n = 2):
    words = []
    initial = []
    for i in range(n):
        if i == (n - 1):
            initial.append("<START>")
        else:
            initial.append(None)
    initial = tuple(initial)
    words.append(random.choice(chain[initial]))
    buffer = list(initial[1:])
    buffer.append(words[-1])
    start_word = tuple(buffer)
    counter = 0
    save = []
    while "<END>" not in start_word:
        next_word = random.choice(chain[start_word])
        words.append(next_word)
        if counter <= n - 3:
            buffer = []
            for j in range(n - counter - 3):
                buffer.append(None)
            if counter == 0:
                buffer.append("<START>")
                buffer.append(words[-2])
                buffer.append(words[-1])
                start_word = tuple(buffer)
                save = start_word
            else:
                buffer = list(save[1:])
                buffer.append(words[-1])
                start_word = tuple(buffer)
                save = start_word
            counter += 1
        else:
            if n == 2:
                start_word = (words[-2],next_word)
            else:
                start_word = list(save)[1:]
                start_word.append(words[-1])
                start_word = tuple(start_word)
        save = start_word

    lyrics = " ".join(words[:-1])
    return "\n".join(lyrics.split("<N>"))

# %%
summary_text = reviews["summary"].str.replace("\s+", " ").str.replace("(\n|\r)","").str.strip().values
review_text = reviews["review"].str.replace("\s+", " ").str.replace("(\n|\r)","").str.strip().values

# %%
chain_summary = train_uni_markov_chain(summary_text)
chain_review = train_uni_markov_chain(review_text)

# %%
print(" Summary: \n",generate_uni_new_script(chain_summary),
      '\n\n',
      "Review: \n",
      generate_uni_new_script(chain_review))
# Out:
#  Summary:
#  Great show so you on cruncyroll!
#
#  Review:
#  I wish the action gets so that kind of naruto && when she does feel more of it stayed throughout the least. Not OK look like a loser by all the oversexualiztion but the main intrigue, suspense, comedy, even more!! I currently all the viewer anytime soon!

# %%
chain_summary = train_n_markov_chain(summary_text, 2)
chain_review = train_n_markov_chain(review_text, 2)

# %%
print(" Summary: \n",generate_n_new_script(chain_summary),
      '\n\n',
      "Review: \n",
      generate_n_new_script(chain_review))
# Out:
#  Summary:
#  I don't write reviews
#
#  Review:
#  Please don't bother reading it or leave me at least... so far also closely follows game logic and efficiency"; "this report is ...

# %%
home_text = home["desc"].str.replace("\s+", " ").str.replace("(\n|\r)","").str.strip().str.lower().values

# %%
chain_desc = train_uni_markov_chain(home_text)

# %%
print(generate_uni_new_script(chain_desc))
# Out:
# in their specialty.

# %%
chain_desc = train_n_markov_chain(home_text, 2)

# %%
print(generate_n_new_script(chain_desc))
# Out:
# at kaimei high school, visits the high school swimming club.
